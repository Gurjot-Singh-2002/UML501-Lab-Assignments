# %% [markdown]
# <a href="https://colab.research.google.com/github/Gurjot-Singh-2002/UML501-Assignments/blob/main/102203582_3CO14_ODD2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])
res = np.flip(arr)
print("Final array", str(res))
# Out:
# Final array [5 4 3 2 1]

# %%
array1=np.array([[1,2,3],[2,4,5],[1,2,3]])
flat = arr.flatten()
print(flat)
# Out:
# [1 2 3 4 5]

# %%
arr1=np.array([[1,2],[3,4]])
arr2=np.array([[1,2],[3,4]])
comparison = arr1 == arr2
equal_arrays = comparison.all()
print(equal_arrays)
# Out:
# True

# %%
x=np.array([1,2,3,4,5,1,2,1,1,1])
print("Most frequent value in above array")
x_count = np.bincount(x)
x_maxf=np.argmax(x_count)
x_indices=np.where(x==x_maxf)[0]
print(x_maxf, x_indices)

y=np.array([1,1,1,2,3,4,2,4,3,3])
print("Most frequent value in above array")
y_count = np.bincount(y)
y_maxf=np.argmax(y_count)
y_indices=np.where(y==y_maxf)[0]
print(y_maxf, y_indices)
# Out:
# Most frequent value in above array
# 1 [0 5 7 8 9]
# Most frequent value in above array
# 1 [0 1 2]

# %%
gfg=np.matrix('[4,1,9;12 3 1; 4,5,6]')
sum = gfg.sum()
print(sum)

print("Sum of each column:")
print(np.sum(gfg, axis=0))

print("Sum of each row:")
print(np.sum(gfg, axis=1))
# Out:
# 45
# Sum of each column:
# [[20  9 16]]
# Sum of each row:
# [[14]
#  [16]
#  [15]]

# %%
n_array=np.array([[55,25,15],[30,44,2],[11,45,77]])
trace = np.trace(n_array)
print("Sum of Diagonal elements=")
print(trace)

evalue, evect = np.linalg.eig(n_array)
print("Eigen Values=")
print(evalue)
print("")
print("Eigen Vectors=")
print(evect)

inv = np.linalg.inv(n_array)
print("Inverse of Matrix=")
print(inv)

deter=np.linalg.det(n_array)
print("Determinant=")
print(deter)
# Out:
# Sum of Diagonal elements=
# 176
# Eigen Values=
# [98.16835147 28.097044   49.73460452]
#
# Eigen Vectors=
# [[ 0.4574917   0.34637121 -0.15017693]
#  [ 0.28447814 -0.72784061 -0.4852124 ]
#  [ 0.84248058  0.59184038  0.8614034 ]]
# Inverse of Matrix=
# [[ 0.02404141 -0.00911212 -0.00444671]
#  [-0.01667882  0.02966905  0.0024785 ]
#  [ 0.00631287 -0.01603732  0.01217379]]
# Determinant=
# 137180.0000000001

# %%
p = [[1, 2], [2, 3]]
q = [[4, 5], [6, 7]]

result = np.dot(p, q)
print("The matrix multiplication is :")
print(result)

covar=np.cov(p,q)
print("\nCovariance matrix of the two arrays:\n", covar)
# Out:
# The matrix multiplication is :
# [[16 19]
#  [26 31]]
#
# Covariance matrix of the two arrays:
#  [[0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5]
#  [0.5 0.5 0.5 0.5]]

# %%
p = [[1, 2], [2, 3], [4, 5]]
q = [[4, 5, 1], [6, 7, 2]]

result = np.dot(p, q)
print("The matrix multiplication is :")
print(result)

covar=np.cov(p,q)
print("\nCovariance matrix of the two arrays:\n", covar)
# Out:
# The matrix multiplication is :
# [[16 19  5]
#  [26 31  8]
#  [46 55 14]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3ff784f93e79> in <cell line: 8>()
#       6 print(result)
#       7
# ----> 8 covar=np.cov(p,q)
#       9 print("\nCovariance matrix of the two arrays:\n", covar)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2681         if not rowvar and y.shape[0] != 1:
#    2682             y = y.T
# -> 2683         X = np.concatenate((X, y), axis=0)
#    2684
#    2685     if ddof is None:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 2 and the array at index 1 has size 3

# %%
x = np.array([[2, 3, 4], [3, 2, 9]])
y = np.array([[1, 5, 0], [5, 10, 3]])

print("\nInner product of matrices x and y =")
print(np.inner(x, y))
print("\nOuter product of vectors a and b =")
print(np.outer(x, y))
print("\nCross product of matrices x and y =")
print(np.cross(x, y))
# Out:
# Inner product of matrices x and y =
# [[17 52]
#  [13 62]]
#
# Outer product of vectors a and b =
# [[ 2 10  0 10 20  6]
#  [ 3 15  0 15 30  9]
#  [ 4 20  0 20 40 12]
#  [ 3 15  0 15 30  9]
#  [ 2 10  0 10 20  6]
#  [ 9 45  0 45 90 27]]
#
# Cross product of matrices x and y =
# [[-20   4   7]
#  [-84  36  20]]

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])

abs_values = np.abs(array)
print("Element-wise absolute values:\n", abs_values)
# Out:
# Element-wise absolute values:
#  [[1 2 3]
#  [4 5 6]]

# %%
percentiles_flattened = np.percentile(array, [25, 50, 75])

# Column-wise percentiles
percentiles_columns = np.percentile(array, [25, 50, 75], axis=0)

# Row-wise percentiles
percentiles_rows = np.percentile(array, [25, 50, 75], axis=1)

# Print results
print("Flattened array percentiles:")
print(f"25th: {percentiles_flattened[0]}")
print(f"50th (Median): {percentiles_flattened[1]}")
print(f"75th: {percentiles_flattened[2]}\n")

print("Column-wise percentiles:")
print(f"25th: {percentiles_columns[0]}")
print(f"50th (Median): {percentiles_columns[1]}")
print(f"75th: {percentiles_columns[2]}\n")

print("Row-wise percentiles:")
print(f"25th: {percentiles_rows[0]}")
print(f"50th (Median): {percentiles_rows[1]}")
print(f"75th: {percentiles_rows[2]}")
# Out:
# Flattened array percentiles:
# 25th: -3.5
# 50th (Median): -0.5
# 75th: 2.5
#
# Column-wise percentiles:
# 25th: [-2.75 -0.25 -3.75]
# 50th (Median): [-1.5  1.5 -1.5]
# 75th: [-0.25  3.25  0.75]
#
# Row-wise percentiles:
# 25th: [-0.5 -5. ]
# 50th (Median): [ 1. -4.]
# 75th: [2.  0.5]

# %%
# Flattened array statistics
flattened_array = array.flatten()
mean_flattened = np.mean(flattened_array)
median_flattened = np.median(flattened_array)
std_flattened = np.std(flattened_array)

# Column-wise statistics
mean_columns = np.mean(array, axis=0)
median_columns = np.median(array, axis=0)
std_columns = np.std(array, axis=0)

# Row-wise statistics
mean_rows = np.mean(array, axis=1)
median_rows = np.median(array, axis=1)
std_rows = np.std(array, axis=1)

print("Flattened array statistics:")
print(f"Mean: {mean_flattened}")
print(f"Median: {median_flattened}")
print(f"Standard Deviation: {std_flattened}\n")

print("Column-wise statistics:")
print(f"Mean: {mean_columns}")
print(f"Median: {median_columns}")
print(f"Standard Deviation: {std_columns}\n")

print("Row-wise statistics:")
print(f"Mean: {mean_rows}")
print(f"Median: {median_rows}")
print(f"Standard Deviation: {std_rows}")
# Out:
# Flattened array statistics:
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224
#
# Column-wise statistics:
# Mean: [-1.5  1.5 -1.5]
# Median: [-1.5  1.5 -1.5]
# Standard Deviation: [2.5 3.5 4.5]
#
# Row-wise statistics:
# Mean: [ 0.66666667 -1.66666667]
# Median: [ 1. -4.]
# Standard Deviation: [2.05480467 4.78423336]

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])
floor = np.floor(a)
ceiling = np.ceil(a)
truncated = np.trunc(a)
rounded = np.round(a)
print("Floor values:", floor)
print("Ceiling values:", ceiling)
print("Truncated values:", truncated)
print("Rounded values:", rounded)
# Out:
# Floor values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])

sorted_array = np.sort(array)
sorted_indices = np.argsort(array)
four_smallest_elements = np.partition(array, 4)[:4]
five_largest_elements = np.partition(array, -5)[-5:]

print("Sorted array:", sorted_array)
print("Indices of sorted array:", sorted_indices)
print("4 smallest elements:", four_smallest_elements)
print("5 largest elements:", five_largest_elements)
# Out:
# Sorted array: [ 10  16  16  52  54  62 453]
# Indices of sorted array: [0 3 4 1 5 2 6]
# 4 smallest elements: [16 10 16 52]
# 5 largest elements: [ 16  52  62  54 453]

# %%
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

integer_elements = array[array == np.floor(array)]
float_elements = array[array != np.floor(array)]

print("Integer elements only:", integer_elements)
print("Float elements only:", float_elements)
# Out:
# Integer elements only: [1. 2. 3. 2.]
# Float elements only: [1.2 2.2]

# %%
import numpy as np
from PIL import Image

def img_to_array(path, output_file='image_array.txt'):
    # Open the image file
    with Image.open(path) as img:
        # Convert image to numpy array
        img_array = np.array(img)

        # Check if the image is RGB or Grayscale
        if len(img_array.shape) == 3:
            # RGB image
            print("Image is in RGB format.")
        elif len(img_array.shape) == 2:
            # Grayscale image
            print("Image is in Grayscale format.")

        # Save the array to a text file
        np.savetxt(output_file, img_array.reshape(-1, img_array.shape[-1]), fmt='%d')
        print(f"Image array saved to {output_file}")

# Use raw string or other solutions for file path
img_to_array(r'C:\Users\revol\Desktop\iamges.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-7a19a4195531> in <cell line: 23>()
#      21
#      22 # Use raw string or other solutions for file path
# ---> 23 img_to_array(r'C:\Users\revol\Desktop\iamges.jpg')
#
# <ipython-input-39-7a19a4195531> in img_to_array(path, output_file)
#       4 def img_to_array(path, output_file='image_array.txt'):
#       5     # Open the image file
# ----> 6     with Image.open(path) as img:
#       7         # Convert image to numpy array
#       8         img_array = np.array(img)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\revol\\Desktop\\iamges.jpg'

# %%
import numpy as np

def load_image_array(file_path, original_shape):
    # Load the array from the text file
    loaded_array = np.loadtxt(file_path, dtype=int)

    # Reshape the array to its original shape
    if len(original_shape) == 3:
        # RGB image
        reshaped_array = loaded_array.reshape(original_shape)
    elif len(original_shape) == 2:
        # Grayscale image
        reshaped_array = loaded_array.reshape(original_shape)

    return reshaped_array

# Example usage
#original_shape = (height, width, channels) for RGB or (height, width) for Grayscale
#image_array = load_image_array('image_array.txt', original_shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-a4ccabde65b2> in <cell line: 19>()
#      17 # Example usage
#      18 original_shape = (44, 33, 22)
# ---> 19 image_array = load_image_array('image_array.txt', original_shape)
#
# <ipython-input-42-a4ccabde65b2> in load_image_array(file_path, original_shape)
#       3 def load_image_array(file_path, original_shape):
#       4     # Load the array from the text file
# ----> 5     loaded_array = np.loadtxt(file_path, dtype=int)
#       6
#       7     # Reshape the array to its original shape
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1371         delimiter = delimiter.decode('latin1')
#    1372
# -> 1373     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374                 converters=converters, skiplines=skiprows, usecols=usecols,
#    1375                 unpack=unpack, ndmin=ndmin, encoding=encoding,
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990             fname = os.fspath(fname)
#     991         if isinstance(fname, str):
# --> 992             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993             if encoding is None:
#     994                 encoding = getattr(fh, 'encoding', 'latin1')
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: image_array.txt not found.
